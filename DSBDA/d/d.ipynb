# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('fb.csv')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
# Page total likes                                                       500 non-null int64
# Type                                                                   500 non-null object
# Category                                                               500 non-null int64
# Post Month                                                             500 non-null int64
# Post Weekday                                                           500 non-null int64
# Post Hour                                                              500 non-null int64
# Paid                                                                   499 non-null float64
# Lifetime Post Total Reach                                              500 non-null int64
# Lifetime Post Total Impressions                                        500 non-null int64
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %% [markdown]
# # CREATING DATA SUBSETS

# %%
df.iloc[1:10,:]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# ...

# %%
df.iloc[1:10,1:6]
# Out:
#      Type  Category  Post Month  Post Weekday  Post Hour
# 1  Status         2          12             3         10
# 2   Photo         3          12             3          3
# 3   Photo         2          12             2         10
# 4   Photo         2          12             2          3
# 5  Status         2          12             1          9
# 6   Photo         3          12             1          3
# 7   Photo         3          12             7          9
# 8  Status         2          12             7          3
# 9   Photo         3          12             6         10

# %%
df.iloc[20:30,[1,4,10,12]]
# Out:
#       Type  Post Weekday  Lifetime Post Consumers  \
# 20   Photo             1                      142
# 21   Photo             7                       15
# 22    Link             7                      104
# 23   Photo             7                      118
# 24  Status             6                     1270
# 25  Status             6                     1462
# 26  Status             5                     2531
# 27   Photo             5                      124
# 28   Photo             5                      559
# 29   Video             4                     1068
#
#     Lifetime Post Impressions by people who have liked your Page
# 20                                               3561
# 21                                               2196
# 22                                               6282
# 23                                               2964
# 24                                               9684
# 25                                              10266
# ...

# %%
df.iloc[[1,25,40,44,100,88],[1,3,5,7,9,11,13]]
# Out:
#        Type  Post Month  Post Hour  Lifetime Post Total Reach  \
# 1    Status          12         10                      10460
# 25   Status          12          3                       8284
# 40   Status          12         11                      13280
# 44    Photo          12         11                       4284
# 100   Photo          10          9                       1357
# 88    Photo          11          3                       1531
#
#      Lifetime Engaged Users  Lifetime Post Consumptions  \
# 1                      1457                        1674
# 25                     1521                        1711
# 40                     2055                        2720
# 44                      355                         513
# 100                      37                          55
# 88                      212                        1359
#
#      Lifetime Post reach by people who like your Page
# 1                                                6112
# ...

# %%
df.iloc[1:10,-4:]
# Out:
#    comment    like  share  Total Interactions
# 1        5   130.0   29.0                 164
# 2        0    66.0   14.0                  80
# 3       58  1572.0  147.0                1777
# 4       19   325.0   49.0                 393
# 5        1   152.0   33.0                 186
# 6        3   249.0   27.0                 279
# 7        0   325.0   14.0                 339
# 8        0   161.0   31.0                 192
# 9        3   113.0   26.0                 142

# %% [markdown]
# # MERGE DATA

# %%
df1 = pd.read_csv("newfb.csv")

# %%
df1.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            136013  Status         2          10             5          3
# 1            136013   Photo         1          10             4         10
# 2            136013    Link         1          10             4          3
# 3            136013  Status         3          10             3         10
# 4            136013  Status         2          10             3          2
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0                       8896                            17202
# 1     1                       4018                             8617
# 2     0                      68992                           229733
# 3     0                      13152                            25666
# 4     1                      31136                            59964
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df1.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        134.000000  134.000000  134.000000    134.000000  134.000000
# mean      132805.373134    1.962687    8.171642      3.940299    7.395522
# std         2490.393437    0.750005    1.051502      2.017820    3.988741
# min       128032.000000    1.000000    7.000000      1.000000    1.000000
# 25%       131300.000000    1.000000    7.000000      2.000000    3.000000
# 50%       132509.000000    2.000000    8.000000      4.000000    9.000000
# 75%       135195.000000    3.000000    9.000000      6.000000   10.000000
# max       136013.000000    3.000000   10.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  134.000000                 134.000000                       134.000000
# mean     0.343284               14206.410448                     28189.365672
# ...

# %%
print(df.shape,df1.shape)
# Out:
# (500, 19) (134, 19)

# %%
df3 = df.append(df1,ignore_index=True)

# %%
df3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
df3.shape
# Out:
# (634, 19)

# %% [markdown]
# # SORT DATA

# %%
df4 = df3.sort_values(by='like',ascending=False)

# %%
df4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791   Photo         2           7             3          5
# 606            130791   Photo         2           7             3          5
# 379            111620   Photo         3           4             1         14
# 349            117764   Photo         3           5             5         13
# 168            135428   Photo         1           9             3         10
# 530            135428   Photo         1           9             3         10
# 3              139441   Photo         2          12             2         10
# 460             92507   Photo         3           2             1         13
# 101            137020   Photo         2          10             4          3
# 323            123047   Photo         3           6             1         10
# 561            132817   Photo         3           8             4         10
# ...

# %%
df4 = df3.sort_values(by='Lifetime Post Consumptions',ascending=True)

# %%
df4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 441             98195   Photo         1           3             5          4
# 76             137893   Photo         1          11             3          2
# 21             138414   Photo         1          12             7         10
# 430            100732    Link         1           3             7         14
# 417            104070   Photo         1           3             3         10
# 111            136736   Photo         1          10             6          8
# 100            137020   Photo         1          10             4          9
# 481             86491    Link         1           1             4          4
# 485             86491    Link         1           1             2          2
# 50             138353   Photo         2          11             1          9
# 438             98195    Link         2           3             6          6
# ...

# %%
df4.shape
# Out:
# (634, 19)

# %% [markdown]
# # TRANSPOSING DATA

# %%
df4 = df3.transpose()

# %%
df4
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                     0       0       0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# # MELTING DATA TO LONG FORMAT

# %%
df3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
df4 = df3.melt()

# %%
for var in df4['variable'].unique():
    print(var)
# Out:
# Page total likes
# Type
# Category
# Post Month
# Post Weekday
# Post Hour
# Paid
# Lifetime Post Total Reach
# Lifetime Post Total Impressions
# Lifetime Engaged Users
# Lifetime Post Consumers
# Lifetime Post Consumptions
# Lifetime Post Impressions by people who have liked your Page
# Lifetime Post reach by people who like your Page
# Lifetime People who have liked your Page and engaged with your post
# comment
# like
# share
# Total Interactions

# %%
df4
# Out:
#                  variable   value
# 0        Page total likes  139441
# 1        Page total likes  139441
# 2        Page total likes  139441
# 3        Page total likes  139441
# 4        Page total likes  139441
# 5        Page total likes  139441
# 6        Page total likes  139441
# 7        Page total likes  139441
# 8        Page total likes  139441
# 9        Page total likes  139441
# 10       Page total likes  139441
# 11       Page total likes  139441
# 12       Page total likes  139441
# 13       Page total likes  139441
# 14       Page total likes  138414
# 15       Page total likes  138414
# 16       Page total likes  138414
# 17       Page total likes  138414
# 18       Page total likes  138414
# 19       Page total likes  138414
# 20       Page total likes  138414
# 21       Page total likes  138414
# 22       Page total likes  138414
# 23       Page total likes  138414
# 24       Page total likes  138414
# 25       Page total likes  138458
# ...

# %%
df4.shape
# Out:
# (12046, 2)

# %%
df4 = df3.melt(id_vars=['Type'],value_vars=['Category','Lifetime Post Consumers'],
               var_name='VARIABLE',value_name='VALUE')

# %%
df4
# Out:
#         Type                 VARIABLE  VALUE
# 0      Photo                 Category      2
# 1     Status                 Category      2
# 2      Photo                 Category      3
# 3      Photo                 Category      2
# 4      Photo                 Category      2
# 5     Status                 Category      2
# 6      Photo                 Category      3
# 7      Photo                 Category      3
# 8     Status                 Category      2
# 9      Photo                 Category      3
# 10    Status                 Category      2
# 11     Photo                 Category      2
# 12     Photo                 Category      2
# 13     Photo                 Category      2
# 14     Photo                 Category      2
# 15    Status                 Category      2
# 16     Photo                 Category      3
# 17     Photo                 Category      1
# 18    Status                 Category      3
# 19     Photo                 Category      3
# ...

# %%
df4.shape
# Out:
# (1268, 3)

# %% [markdown]
# # Casting Data To Wide Format

# %%
df3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
df4 = df3.iloc[[0,1,2],[1,2,7]]

# %%
df4
# Out:
#      Type  Category  Lifetime Post Total Reach
# 0   Photo         2                       2752
# 1  Status         2                      10460
# 2   Photo         3                       2413

# %%
df4.drop_duplicates(inplace=True)

# %%
df4.reset_index(drop=True, inplace=True)

# %%
df4.pivot(index='Type',columns='Category',values='Lifetime Post Total Reach')
# Out:
# Category        2       3
# Type
# Photo      2752.0  2413.0
# Status    10460.0     NaN
