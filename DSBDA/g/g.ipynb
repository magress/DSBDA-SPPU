# %%
import pandas as dp

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data=dp.read_csv('C:\\Users\\admin\\Desktop\\datasets\\fb.csv')

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
A=data.iloc[0:10,0:8]

# %%
X=A['Post Weekday']
Y=A['Lifetime Post Total Reach']

plt.plot(X,Y)

plt.title=('Line graph')

# %%
X=A['Post Weekday']
Y=A['Lifetime Post Total Reach']

plt.bar(X,Y,align='center')

plt.title=('Bar graph')

# %%
X=A['Post Weekday']
Y=A['Lifetime Post Total Reach']
plt.scatter(X,Y)

# %%
X=A['Post Weekday']
Y=A['Lifetime Post Total Reach']

# %%
import seaborn as sns

# %%
X=A['Post Weekday']
Y=A['Lifetime Post Total Reach']

plt.scatter(Y,X,s=1000,alpha=0.5)

# %%
X=A['Post Weekday']
Y=A['Lifetime Post Total Reach']
plt.stackplot(X,Y)

# %%
X=A['Post Weekday']
Y=A['Lifetime Post Total Reach']
plt.pie( Y,
    pctdistance=0.6,
    labeldistance=1.1,
    center=(0, 0),
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x1a54e251f60>,
# ...
#  [Text(1.0973874736810274, 0.07576762242523116, ''),
#   Text(1.0132190471430023, 0.42823727360731545, ''),
#   Text(0.8252928786542847, 0.7272493825659285, ''),
#   Text(-0.4958424215753846, 0.9819064583585642, ''),
#   Text(-1.0392394289209341, -0.3605293460678216, ''),
#   Text(-0.7837903145853141, -0.7717983821972255, ''),
#   Text(-0.25925614306937983, -1.0690118111044373, ''),
#   Text(0.4269552063596334, -1.0137599576637475, ''),
#   Text(0.9480653844504994, -0.5578279544866204, ''),
#   Text(1.0924051060090738, -0.12903908076743323, '')])

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(),cmap='coolwarm')
